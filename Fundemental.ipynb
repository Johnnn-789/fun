# %%
•  The Goal: Ask the user for various words (nouns, adjectives, verbs) using input(), store them in variables, and then inject them into a funny pre-written story using f-strings and print().

# %%
user_guess = input("Enter a noun")
user_claim = input("Enter a verb")
user_friendly = input("Enter an adjective")
print(f"She is a,{user_guess}.She {user_claim} with her parents.In her free time she likes to play football with her male friends.She is kind of {user_friendly} girl")
# Out:
# Enter a noun u
# Enter a verb j
# Enter an adjective k
# She is a,u.She j with her parents.In her free time she likes to play football with her male friends.She is kind of k girl

# %%
• The Goal: Ask the user for the total bill amount and the percentage they want to tip. Calculate the tip amount and the grand total, rounding the output to two decimal places.

# %%
Bill = float(input("Enter total bill"))
Percentage = float(input("Enter tip percentage")) 
Tip = Bill * Percentage/100
Total = Bill + Tip
print(f"the tip is: {Tip}")
print(f"the Total is: {Total}")
# Out:
# Enter total bill 50
# Enter tip percentage 5
# the tip is: 2.5
# the Total is: 52.5

# %%
• The Goal: Ask the user for the total distance of their planned road trip (in km), their car's average KPL (kilometers per liter), and the current price of fuel per liter. Calculate how many liter they will need and the total estimated cost of the trip, outputting a cleanly formatted summary with the total rounded to two decimal places.

# %%
Total_distance = float(input("Distance in km"))
Car_efficiency = float(input("Km per litre"))
Fuel_price = float(input("Per liter"))
Fuel = Total_distance * Car_efficiency
Cost = Fuel *Fuel_price
print(f"The fuel of car is: {Fuel}")
print(f"The cost of trip: {Cost}")
# Out:
# Distance in km 100
# Km per litre 5
# Per liter 3000
# The fuel of car is: 500.0
# The cost of trip: 1500000.0
